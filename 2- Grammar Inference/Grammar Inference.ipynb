# %%
import pandas as pd
import numpy as np
import math

# %% [markdown]
# ## Creation of the FPTA
#
# In order to be able to make our predictions, we first need to create our prefix tree, representing all the possible sequences read by the tree.
#
# We start by creating the *TrieNode* class. It represents a node of our tree. It takes as attribute:
# - a string of characters 'text', which represents the label of each node.
# - an 'is_word' boolean initialized to False. It becomes True if it has no children (i.e. if the word is finished).
# - a list of children, to which we initialize for all nodes the first element representing the number of words ending at this node (completes the boolean presented above)
# - an integer 'state', which represents the id of the node. It is unique for each node of the tree.
# - an 'is_displayed' boolean initialized to False. It is used when displaying the tree, when there are loops so that it is displayed only once.
# - a list of precedents, which grows as you go. All the precedents of each node are added to it. For the root node, we consider that its predecessor is itself.
#
# For the *PrefixTree* class, which represents the tree as such, we have:
# - a *TrieNode* which represents the root node.
# - class functions that we will detail below

# %% [markdown]
# ### Class functions of the *PrefixTree*.
#
# #### Insert function:
# It allows us to insert a word (taken as a parameter), starting from a certain node (current parameter). To do so, we enumerate the word (each character is taken one by one with its corresponding index), then, if the character is not present in the list of children, we will create a node and then increment the indices. If there already exists a child node with the same character, we increment its frequency by 1. When the word is finished, we pass the boolean to True, and we increment the word counter by 1.
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/b/be/Trie_example.svg/1200px-Trie_example.svg.png" alt="Drawing" style="width: 200px;"/>

# %%
class TrieNode:
    _COUNTER_NODE = 1
    def __init__(self, text = "λ"):
        self.text = text
        self.is_word = False
        self.children = list()
        self.children.append(['#', 0, self]) #1st element:SYMB 2nd element:FREQUENCY 3rd element:CHILDREN 
        self.state = TrieNode._COUNTER_NODE
        TrieNode._COUNTER_NODE += 1
        self.previous = []

    def get_frequency(self): # Not counting the number of times a word ends 
        freq = 0
        for child in self.children[1:]:
            freq += child[1]
        return freq
    
    def get_frequency2(self):
        freq = 0
        for child in self.children:
            freq += child[1]
        return freq

    def __str__(self):
        return 'symb:{} state:{} -> children:{}'.format(self.text, self.state, self.children)

class PrefixTree:
    def __init__(self):
        self.root = TrieNode()
        self.matrice_transition = pd.DataFrame()
        self.matrice_emission = pd.DataFrame()

    def insert(self, word, current = None):
        '''
        Creates a given word in the trie
        '''
        if not current: 
            current = self.root
            pre = self.root
            
        for i, char in enumerate(word):
            
            if char not in [x[0] for x in current.children]:
                prefix = word[0:i+1]
                current.children.append([char, 1, TrieNode(prefix)])
                
                if pre not in current.previous:
                    current.previous.append(pre)
                    
                pre = current
                current = current.children[-1][2]

            else:
                for child in current.children:
                    if child[0] == char:
                        child[1] += 1
                        
                        if pre not in current.previous:
                            current.previous.append(pre)
                            
                        pre = current
                        current = child[2]

        current.is_word = True   
        current.children[0][1] += 1
        
    def starts_with(self, prefix, current = None):
        '''
        Returns a list of all words beginning with the given prefix, or
        an empty list if no words begin with that prefix.
        '''
        words = list()
        if not current:
            current = self.root
        for char in prefix:
            if char not in [x[0] for x in current.children]:
                return list()
            for child in current.children:
                  if child[0] == char:
                    current = child[2]
        self.__child_words_for(current, words)
        return words
    
    def __child_words_for(self, node, words):
        '''
        Private helper function. Cycles through all children
        of node recursively, adding them to words if they
        constitute whole words (as opposed to merely prefixes).
        '''
        if node.is_word:
            words.append(node.text)
        for child in node.children[1:]:
            self.__child_words_for(child[2], words)
    
    def size(self, current = None, visited = None):
        '''
        Returns the size of this prefix tree, defined
        as the total number of nodes in the tree.
        '''
        # By default, get the size of the whole trie, starting at the root
        if not current:
            current = self.root
        
        if not visited:
            visited = []
            visited.append(current)
            
        count = 1
        
        for child in current.children[1:]:
            if(child[2] not in visited):
                visited.append(child[2])
                count += self.size(child[2], visited)
                
        return count

    def leaf(self, current = None, visited = None):
        if not current: 
            current = self.root
            
        if not visited:
            visited = []
            
        count = 0
        tmp = 0
        
        self.__child_words_for(current, count)        
        return count
    
    def __leaves_for(self, current, count, visited):
        if current.is_word == True:
            count += 1
        for child in current.children[1:]:
            if(child[2] not in visited):
                visited.append(child[2])
                self.__leaves_for(child[2], count, visited)
    
    def transform2proba(self, current = None):
        if not current:
            current = self.root
            
        freq = current.get_frequency2()
        for child in current.children:
            if(isinstance(child[1], int) == False):
                return 0
            else: 
                child[1] = child[1]/freq
                if child[2].state != current.state:
                    current = child[2]    
                    self.transform2proba(current)
                    
    def display(self):
        '''
        Prints the contents of this prefix tree.
        '''
        print('====================================================================================')
        self.__displayHelper(self.root)
        print('====================================================================================\n')
    
    def __displayHelper(self, current, visited = None):
        '''
        Private helper for printing the contents of this prefix tree.
        '''
        if not visited: 
            visited = []
            visited.append(current)
        
        print(current, "\n")
        
        for child in current.children[1:]:
            if child[2] not in visited:
                visited.append(current)
                self.__displayHelper(child[2], visited)

# %%
file = open("../1- Data Analysis/sequences.txt", "r")

seq = []
for line in file:
    stripped_line = line.strip()
    seq.append(stripped_line)

file.close()

# %%
trie = PrefixTree()
for seqq in seq:
    trie.insert(seqq)
    
trie.display()
# Out:
# ====================================================================================
# symb:λ state:1 -> children:[['#', 0, <__main__.TrieNode object at 0x000001D9EDD0A588>], ['9', 14, <__main__.TrieNode object at 0x000001D9EDCE7648>], ['1', 24, <__main__.TrieNode object at 0x000001D9EDCE7948>], ['7', 11, <__main__.TrieNode object at 0x000001D9EBAEE948>], ['8', 89, <__main__.TrieNode object at 0x000001D9EDCE8388>], ['3', 20, <__main__.TrieNode object at 0x000001D9EDCE8E88>], ['0', 60, <__main__.TrieNode object at 0x000001D9EDCE86C8>], ['2', 33, <__main__.TrieNode object at 0x000001D9EDCE8D48>], ['4', 55, <__main__.TrieNode object at 0x000001D9EDCE8788>], ['6', 27, <__main__.TrieNode object at 0x000001D9EDCCAC48>], ['5', 38, <__main__.TrieNode object at 0x000001D9EDCCC348>]]
#
# symb:9 state:2 -> children:[['#', 0, <__main__.TrieNode object at 0x000001D9EDCE7648>], ['6', 3, <__main__.TrieNode object at 0x000001D9EDCE7FC8>], ['8', 5, <__main__.TrieNode object at 0x000001D9EDCCF3C8>], ['4', 2, <__main__.TrieNode object at 0x000001D9EDCD52C8>], ['5', 2, <__main__.TrieNode object at 0x000001D9EDCCA248>], ['0', 2, <__main__.TrieNode object at 0x000001D9EDCD5FC8>]]
#
# symb:96 state:3 -> children:[['#', 2, <__main__.TrieNode object at 0x000001D9EDCE7FC8>], ['0', 1, <__main__.TrieNode object at 0x000001D9EDC73B08>]]
#
# symb:960 state:115 -> children:[['#', 1, <__main__.TrieNode object at 0x000001D9EDC73B08>]]
#
# symb:98 state:44 -> children:[['#', 5, <__main__.TrieNode object at 0x000001D9EDCCF3C8>]]
#
# symb:94 state:67 -> children:[['#', 2, <__main__.TrieNode object at 0x000001D9EDCD52C8>]]
#
# symb:95 state:94 -> children:[['#', 2, <__main__.TrieNode object at 0x000001D9EDCCA248>]]
#
# symb:90 state:112 -> children:[['#', 2, <__main__.TrieNode object at 0x000001D9EDCD5FC8>]]
#
# symb:1 state:4 -> children:[['#', 0, <__main__.TrieNode object at 0x000001D9EDCE7948>], ['0', 2, <__main__.TrieNode object at 0x000001D9EDCE7A48>], ['9', 1, <__main__.TrieNode object at 0x000001D9EDCE8508>], ['2', 10, <__main__.TrieNode object at 0x000001D9EDCE85C8>], ['6', 2, <__main__.TrieNode object at 0x000001D9EDCCAB88>], ['5', 5, <__main__.TrieNode object at 0x000001D9EDCCC248>], ['8', 2, <__main__.TrieNode object at 0x000001D9EDCD5748>], ['7', 1, <__main__.TrieNode object at 0x000001D9EDC30448>], ['4', 1, <__main__.TrieNode object at 0x000001D9EDC30D08>]]
#
# symb:10 state:5 -> children:[['#', 2, <__main__.TrieNode object at 0x000001D9EDCE7A48>]]
#
# symb:19 state:8 -> children:[['#', 1, <__main__.TrieNode object at 0x000001D9EDCE8508>]]
#
# symb:12 state:18 -> children:[['#', 10, <__main__.TrieNode object at 0x000001D9EDCE85C8>]]
#
# symb:16 state:29 -> children:[['#', 2, <__main__.TrieNode object at 0x000001D9EDCCAB88>]]
#
# symb:15 state:38 -> children:[['#', 4, <__main__.TrieNode object at 0x000001D9EDCCC248>], ['8', 1, <__main__.TrieNode object at 0x000001D9EDCCC4C8>]]
#
# symb:158 state:39 -> children:[['#', 0, <__main__.TrieNode object at 0x000001D9EDCCC4C8>], ['3', 1, <__main__.TrieNode object at 0x000001D9EDCCC488>]]
#
# symb:1583 state:40 -> children:[['#', 1, <__main__.TrieNode object at 0x000001D9EDCCC488>]]
#
# symb:18 state:81 -> children:[['#', 2, <__main__.TrieNode object at 0x000001D9EDCD5748>]]
#
# symb:17 state:91 -> children:[['#', 1, <__main__.TrieNode object at 0x000001D9EDC30448>]]
#
# symb:14 state:93 -> children:[['#', 1, <__main__.TrieNode object at 0x000001D9EDC30D08>]]
#
# symb:7 state:6 -> children:[['#', 0, <__main__.TrieNode object at 0x000001D9EBAEE948>], ['2', 5, <__main__.TrieNode object at 0x000001D9EDCE84C8>], ['5', 1, <__main__.TrieNode object at 0x000001D9EDCD10C8>], ['4', 3, <__main__.TrieNode object at 0x000001D9EDCD9688>], ['6', 1, <__main__.TrieNode object at 0x000001D9EDC30608>], ['1', 1, <__main__.TrieNode object at 0x000001D9EDC8E508>]]
#
# symb:72 state:7 -> children:[['#', 5, <__main__.TrieNode object at 0x000001D9EDCE84C8>]]
#
# symb:75 state:50 -> children:[['#', 1, <__main__.TrieNode object at 0x000001D9EDCD10C8>]]
#
# symb:74 state:82 -> children:[['#', 2, <__main__.TrieNode object at 0x000001D9EDCD9688>], ['9', 1, <__main__.TrieNode object at 0x000001D9EDCD9BC8>]]
#
# symb:749 state:83 -> children:[['#', 1, <__main__.TrieNode object at 0x000001D9EDCD9BC8>]]
#
# symb:76 state:88 -> children:[['#', 1, <__main__.TrieNode object at 0x000001D9EDC30608>]]
#
# symb:71 state:103 -> children:[['#', 1, <__main__.TrieNode object at 0x000001D9EDC8E508>]]
#
# symb:8 state:9 -> children:[['#', 0, <__main__.TrieNode object at 0x000001D9EDCE8388>], ['0', 11, <__main__.TrieNode object at 0x000001D9EDCE8EC8>], ['4', 22, <__main__.TrieNode object at 0x000001D9EDCE8748>], ['5', 14, <__main__.TrieNode object at 0x000001D9EDCE8CC8>], ['6', 14, <__main__.TrieNode object at 0x000001D9EDCE8448>], ['2', 16, <__main__.TrieNode object at 0x000001D9EDCE8688>], ['3', 7, <__main__.TrieNode object at 0x000001D9EDCE8C08>], ['1', 4, <__main__.TrieNode object at 0x000001D9EBB9B6C8>], ['9', 1, <__main__.TrieNode object at 0x000001D9EDC93348>]]
#
# symb:80 state:10 -> children:[['#', 10, <__main__.TrieNode object at 0x000001D9EDCE8EC8>], ['6', 1, <__main__.TrieNode object at 0x000001D9EDCE82C8>]]
#
# symb:806 state:11 -> children:[['#', 1, <__main__.TrieNode object at 0x000001D9EDCE82C8>]]
#
# symb:84 state:14 -> children:[['#', 22, <__main__.TrieNode object at 0x000001D9EDCE8748>]]
#
# symb:85 state:15 -> children:[['#', 12, <__main__.TrieNode object at 0x000001D9EDCE8CC8>], ['2', 2, <__main__.TrieNode object at 0x000001D9EDC30548>]]
#
# symb:852 state:89 -> children:[['#', 2, <__main__.TrieNode object at 0x000001D9EDC30548>]]
#
# symb:86 state:19 -> children:[['#', 12, <__main__.TrieNode object at 0x000001D9EDCE8448>], ['0', 1, <__main__.TrieNode object at 0x000001D9EDCE8F48>], ['9', 1, <__main__.TrieNode object at 0x000001D9EDC86A08>]]
#
# symb:860 state:20 -> children:[['#', 1, <__main__.TrieNode object at 0x000001D9EDCE8F48>]]
#
# symb:869 state:110 -> children:[['#', 1, <__main__.TrieNode object at 0x000001D9EDC86A08>]]
#
# symb:82 state:21 -> children:[['#', 13, <__main__.TrieNode object at 0x000001D9EDCE8688>], ['0', 2, <__main__.TrieNode object at 0x000001D9EDCE8648>], ['1', 1, <__main__.TrieNode object at 0x000001D9EDC7C888>]]
#
# symb:820 state:22 -> children:[['#', 2, <__main__.TrieNode object at 0x000001D9EDCE8648>]]
#
# symb:821 state:107 -> children:[['#', 1, <__main__.TrieNode object at 0x000001D9EDC7C888>]]
#
# symb:83 state:28 -> children:[['#', 7, <__main__.TrieNode object at 0x000001D9EDCE8C08>]]
#
# symb:81 state:68 -> children:[['#', 4, <__main__.TrieNode object at 0x000001D9EBB9B6C8>]]
#
# symb:89 state:86 -> children:[['#', 1, <__main__.TrieNode object at 0x000001D9EDC93348>]]
#
# symb:3 state:12 -> children:[['#', 0, <__main__.TrieNode object at 0x000001D9EDCE8E88>], ['0', 5, <__main__.TrieNode object at 0x000001D9EDCE8F08>], ['4', 3, <__main__.TrieNode object at 0x000001D9EDCE8B08>], ['1', 4, <__main__.TrieNode object at 0x000001D9EDCD1B88>], ['8', 3, <__main__.TrieNode object at 0x000001D9EDCD5588>], ['6', 3, <__main__.TrieNode object at 0x000001D9EDCD99C8>], ['9', 1, <__main__.TrieNode object at 0x000001D9EDCD1788>], ['2', 1, <__main__.TrieNode object at 0x000001D9EDC8EE08>]]
#
# symb:30 state:13 -> children:[['#', 5, <__main__.TrieNode object at 0x000001D9EDCE8F08>]]
#
# symb:34 state:23 -> children:[['#', 3, <__main__.TrieNode object at 0x000001D9EDCE8B08>]]
#
# symb:31 state:55 -> children:[['#', 3, <__main__.TrieNode object at 0x000001D9EDCD1B88>], ['8', 1, <__main__.TrieNode object at 0x000001D9EDCD5D88>]]
#
# symb:318 state:59 -> children:[['#', 1, <__main__.TrieNode object at 0x000001D9EDCD5D88>]]
#
# symb:38 state:61 -> children:[['#', 2, <__main__.TrieNode object at 0x000001D9EDCD5588>], ['0', 1, <__main__.TrieNode object at 0x000001D9EDCD5088>]]
#
# symb:380 state:62 -> children:[['#', 1, <__main__.TrieNode object at 0x000001D9EDCD5088>]]
#
# symb:36 state:73 -> children:[['#', 2, <__main__.TrieNode object at 0x000001D9EDCD99C8>], ['2', 1, <__main__.TrieNode object at 0x000001D9EDCD9C88>]]
#
# symb:362 state:75 -> children:[['#', 1, <__main__.TrieNode object at 0x000001D9EDCD9C88>]]
#
# symb:39 state:97 -> children:[['#', 1, <__main__.TrieNode object at 0x000001D9EDCD1788>]]
#
# symb:32 state:102 -> children:[['#', 1, <__main__.TrieNode object at 0x000001D9EDC8EE08>]]
#
# symb:0 state:16 -> children:[['#', 0, <__main__.TrieNode object at 0x000001D9EDCE86C8>], ['8', 15, <__main__.TrieNode object at 0x000001D9EDCE8BC8>], ['6', 9, <__main__.TrieNode object at 0x000001D9EDCDA408>], ['9', 2, <__main__.TrieNode object at 0x000001D9EDCCCF88>], ['3', 15, <__main__.TrieNode object at 0x000001D9EDCCC448>], ['4', 11, <__main__.TrieNode object at 0x000001D9EDCCF308>], ['1', 3, <__main__.TrieNode object at 0x000001D9EDCD18C8>], ['2', 3, <__main__.TrieNode object at 0x000001D9EDCD9048>], ['5', 2, <__main__.TrieNode object at 0x000001D9EDC89D88>]]
#
# symb:08 state:17 -> children:[['#', 15, <__main__.TrieNode object at 0x000001D9EDCE8BC8>]]
#
# symb:06 state:33 -> children:[['#', 9, <__main__.TrieNode object at 0x000001D9EDCDA408>]]
#
# symb:09 state:42 -> children:[['#', 1, <__main__.TrieNode object at 0x000001D9EDCCCF88>], ['6', 1, <__main__.TrieNode object at 0x000001D9EDCD9908>]]
#
# symb:096 state:78 -> children:[['#', 1, <__main__.TrieNode object at 0x000001D9EDCD9908>]]
#
# symb:03 state:43 -> children:[['#', 13, <__main__.TrieNode object at 0x000001D9EDCCC448>], ['8', 1, <__main__.TrieNode object at 0x000001D9EDC7C988>], ['4', 1, <__main__.TrieNode object at 0x000001D9EDC72048>]]
#
# symb:038 state:106 -> children:[['#', 1, <__main__.TrieNode object at 0x000001D9EDC7C988>]]
#
# symb:034 state:113 -> children:[['#', 1, <__main__.TrieNode object at 0x000001D9EDC72048>]]
#
# symb:04 state:45 -> children:[['#', 9, <__main__.TrieNode object at 0x000001D9EDCCF308>], ['6', 1, <__main__.TrieNode object at 0x000001D9EDCD5B88>], ['3', 1, <__main__.TrieNode object at 0x000001D9EDC30688>]]
#
# symb:046 state:58 -> children:[['#', 1, <__main__.TrieNode object at 0x000001D9EDCD5B88>]]
#
# symb:043 state:95 -> children:[['#', 1, <__main__.TrieNode object at 0x000001D9EDC30688>]]
#
# symb:01 state:56 -> children:[['#', 3, <__main__.TrieNode object at 0x000001D9EDCD18C8>]]
#
# symb:02 state:74 -> children:[['#', 2, <__main__.TrieNode object at 0x000001D9EDCD9048>], ['8', 1, <__main__.TrieNode object at 0x000001D9EDC73BC8>]]
#
# symb:028 state:114 -> children:[['#', 1, <__main__.TrieNode object at 0x000001D9EDC73BC8>]]
#
# symb:05 state:100 -> children:[['#', 1, <__main__.TrieNode object at 0x000001D9EDC89D88>], ['8', 1, <__main__.TrieNode object at 0x000001D9EDCCC788>]]
#
# symb:058 state:101 -> children:[['#', 1, <__main__.TrieNode object at 0x000001D9EDCCC788>]]
#
# symb:2 state:24 -> children:[['#', 0, <__main__.TrieNode object at 0x000001D9EDCE8D48>], ['7', 1, <__main__.TrieNode object at 0x000001D9EDCE8D08>], ['0', 7, <__main__.TrieNode object at 0x000001D9EDCDA388>], ['1', 4, <__main__.TrieNode object at 0x000001D9EDCCF688>], ['6', 4, <__main__.TrieNode object at 0x000001D9EDCD1908>], ['8', 9, <__main__.TrieNode object at 0x000001D9EDCD1948>], ['5', 4, <__main__.TrieNode object at 0x000001D9EDCD1808>], ['3', 2, <__main__.TrieNode object at 0x000001D9EDC308C8>], ['9', 2, <__main__.TrieNode object at 0x000001D9EDC7E988>]]
#
# symb:27 state:25 -> children:[['#', 1, <__main__.TrieNode object at 0x000001D9EDCE8D08>]]
#
# symb:20 state:32 -> children:[['#', 7, <__main__.TrieNode object at 0x000001D9EDCDA388>]]
#
# symb:21 state:47 -> children:[['#', 4, <__main__.TrieNode object at 0x000001D9EDCCF688>]]
#
# symb:26 state:48 -> children:[['#', 3, <__main__.TrieNode object at 0x000001D9EDCD1908>], ['8', 1, <__main__.TrieNode object at 0x000001D9EDC30B08>]]
#
# symb:268 state:92 -> children:[['#', 1, <__main__.TrieNode object at 0x000001D9EDC30B08>]]
#
# symb:28 state:51 -> children:[['#', 9, <__main__.TrieNode object at 0x000001D9EDCD1948>]]
#
# symb:25 state:57 -> children:[['#', 4, <__main__.TrieNode object at 0x000001D9EDCD1808>]]
#
# symb:23 state:90 -> children:[['#', 2, <__main__.TrieNode object at 0x000001D9EDC308C8>]]
#
# symb:29 state:96 -> children:[['#', 2, <__main__.TrieNode object at 0x000001D9EDC7E988>]]
#
# symb:4 state:26 -> children:[['#', 0, <__main__.TrieNode object at 0x000001D9EDCE8788>], ['8', 23, <__main__.TrieNode object at 0x000001D9EDCE8348>], ['0', 10, <__main__.TrieNode object at 0x000001D9EDCCC688>], ['5', 6, <__main__.TrieNode object at 0x000001D9EDCD1408>], ['9', 3, <__main__.TrieNode object at 0x000001D9EDCD5288>], ['6', 4, <__main__.TrieNode object at 0x000001D9EBB6B288>], ['2', 2, <__main__.TrieNode object at 0x000001D9EDCD91C8>], ['1', 2, <__main__.TrieNode object at 0x000001D9EDCD9EC8>], ['7', 3, <__main__.TrieNode object at 0x000001D9EDCD90C8>], ['3', 2, <__main__.TrieNode object at 0x000001D9EDC93448>]]
#
# symb:48 state:27 -> children:[['#', 22, <__main__.TrieNode object at 0x000001D9EDCE8348>], ['3', 1, <__main__.TrieNode object at 0x000001D9EDCD5EC8>]]
#
# symb:483 state:60 -> children:[['#', 1, <__main__.TrieNode object at 0x000001D9EDCD5EC8>]]
#
# symb:40 state:41 -> children:[['#', 10, <__main__.TrieNode object at 0x000001D9EDCCC688>]]
#
# symb:45 state:54 -> children:[['#', 6, <__main__.TrieNode object at 0x000001D9EDCD1408>]]
#
# symb:49 state:66 -> children:[['#', 3, <__main__.TrieNode object at 0x000001D9EDCD5288>]]
#
# symb:46 state:72 -> children:[['#', 3, <__main__.TrieNode object at 0x000001D9EBB6B288>], ['5', 1, <__main__.TrieNode object at 0x000001D9EDCD9248>]]
#
# symb:465 state:79 -> children:[['#', 1, <__main__.TrieNode object at 0x000001D9EDCD9248>]]
#
# symb:42 state:76 -> children:[['#', 2, <__main__.TrieNode object at 0x000001D9EDCD91C8>]]
#
# symb:41 state:77 -> children:[['#', 2, <__main__.TrieNode object at 0x000001D9EDCD9EC8>]]
#
# symb:47 state:80 -> children:[['#', 3, <__main__.TrieNode object at 0x000001D9EDCD90C8>]]
#
# symb:43 state:85 -> children:[['#', 2, <__main__.TrieNode object at 0x000001D9EDC93448>]]
#
# symb:6 state:30 -> children:[['#', 0, <__main__.TrieNode object at 0x000001D9EDCCAC48>], ['5', 6, <__main__.TrieNode object at 0x000001D9EDCDA848>], ['8', 6, <__main__.TrieNode object at 0x000001D9EDCDA108>], ['4', 5, <__main__.TrieNode object at 0x000001D9EDCCC308>], ['3', 2, <__main__.TrieNode object at 0x000001D9EDCD5CC8>], ['0', 4, <__main__.TrieNode object at 0x000001D9EDCD9E88>], ['1', 1, <__main__.TrieNode object at 0x000001D9EBB11548>], ['2', 2, <__main__.TrieNode object at 0x000001D9EDC8E288>], ['9', 1, <__main__.TrieNode object at 0x000001D9EDC86D88>]]
#
# symb:65 state:31 -> children:[['#', 6, <__main__.TrieNode object at 0x000001D9EDCDA848>]]
#
# symb:68 state:34 -> children:[['#', 6, <__main__.TrieNode object at 0x000001D9EDCDA108>]]
#
# symb:64 state:35 -> children:[['#', 5, <__main__.TrieNode object at 0x000001D9EDCCC308>]]
#
# symb:63 state:63 -> children:[['#', 2, <__main__.TrieNode object at 0x000001D9EDCD5CC8>]]
#
# symb:60 state:84 -> children:[['#', 3, <__main__.TrieNode object at 0x000001D9EDCD9E88>], ['5', 1, <__main__.TrieNode object at 0x000001D9EDC7E488>]]
#
# symb:605 state:98 -> children:[['#', 1, <__main__.TrieNode object at 0x000001D9EDC7E488>]]
#
# symb:61 state:99 -> children:[['#', 1, <__main__.TrieNode object at 0x000001D9EBB11548>]]
#
# symb:62 state:104 -> children:[['#', 2, <__main__.TrieNode object at 0x000001D9EDC8E288>]]
#
# symb:69 state:111 -> children:[['#', 1, <__main__.TrieNode object at 0x000001D9EDC86D88>]]
#
# symb:5 state:36 -> children:[['#', 0, <__main__.TrieNode object at 0x000001D9EDCCC348>], ['6', 4, <__main__.TrieNode object at 0x000001D9EDCCC108>], ['0', 6, <__main__.TrieNode object at 0x000001D9EDCCF288>], ['2', 3, <__main__.TrieNode object at 0x000001D9EDCD1748>], ['8', 14, <__main__.TrieNode object at 0x000001D9EDCD1448>], ['9', 3, <__main__.TrieNode object at 0x000001D9EDCD5648>], ['3', 4, <__main__.TrieNode object at 0x000001D9EBB9B988>], ['4', 3, <__main__.TrieNode object at 0x000001D9EDCE8608>], ['1', 1, <__main__.TrieNode object at 0x000001D9EDC7F848>]]
#
# symb:56 state:37 -> children:[['#', 4, <__main__.TrieNode object at 0x000001D9EDCCC108>]]
#
# symb:50 state:46 -> children:[['#', 5, <__main__.TrieNode object at 0x000001D9EDCCF288>], ['4', 1, <__main__.TrieNode object at 0x000001D9EDCD1148>]]
#
# symb:504 state:109 -> children:[['#', 1, <__main__.TrieNode object at 0x000001D9EDCD1148>]]
#
# symb:52 state:49 -> children:[['#', 3, <__main__.TrieNode object at 0x000001D9EDCD1748>]]
#
# symb:58 state:52 -> children:[['#', 12, <__main__.TrieNode object at 0x000001D9EDCD1448>], ['0', 1, <__main__.TrieNode object at 0x000001D9EDCD1E48>], ['2', 1, <__main__.TrieNode object at 0x000001D9EDC7C348>]]
#
# symb:580 state:53 -> children:[['#', 1, <__main__.TrieNode object at 0x000001D9EDCD1E48>]]
#
# symb:582 state:105 -> children:[['#', 1, <__main__.TrieNode object at 0x000001D9EDC7C348>]]
#
# symb:59 state:64 -> children:[['#', 2, <__main__.TrieNode object at 0x000001D9EDCD5648>], ['6', 1, <__main__.TrieNode object at 0x000001D9EDCD59C8>]]
#
# symb:596 state:65 -> children:[['#', 1, <__main__.TrieNode object at 0x000001D9EDCD59C8>]]
#
# symb:53 state:69 -> children:[['#', 3, <__main__.TrieNode object at 0x000001D9EBB9B988>], ['8', 1, <__main__.TrieNode object at 0x000001D9EDC0E388>]]
#
# symb:538 state:70 -> children:[['#', 0, <__main__.TrieNode object at 0x000001D9EDC0E388>], ['6', 1, <__main__.TrieNode object at 0x000001D9EBB6B688>]]
#
# symb:5386 state:71 -> children:[['#', 1, <__main__.TrieNode object at 0x000001D9EBB6B688>]]
#
# symb:54 state:87 -> children:[['#', 3, <__main__.TrieNode object at 0x000001D9EDCE8608>]]
#
# symb:51 state:108 -> children:[['#', 1, <__main__.TrieNode object at 0x000001D9EDC7F848>]]
#
# ====================================================================================

# %% [markdown]
# ## Creation of the DFA with the FPTA:
#
# To transform a prefix tree into a frequency automaton (and thus probabilistic), a state-merging algorithm is used. Currently, the best one has been created by Colin de la Higuera. It is implemented from scratch below:
#
# First of all, we have in parameters the sequences and an alpha parameter [0, 1].
# We create the tree then we initialize 2 lists: red & blue:
# - Red stores all nodes that have already been defined as representative nodes and will be included in the final output model.
# - Blue stores nodes that have not yet been tested.
#
# The purpose of the algorithm is to keep only the red states. At the beginning,RED contains only the root node, whileBlue contains the immediate successor nodes of the initial node: the child nodes of the root. When executing the external loop of the algorithm, the first qb node in BLUE is chosen. If there is a qr node in RED compatible with qb, then qb and its successor nodes are merged with qr and the corresponding successor nodes of qr, respectively, as described in the Merge&Fold part. If qb is not compatible with any of the states of RED, it will be promoted, i.e. it will switch to RED, and its respective children will switch to BLUE.
#
# #### Merge&Fold operation:
# Given the DFA, the merge operation takes 2 states q and q′, where q is a RED state and q′ is a BLUE state compatible with the Hoeffding test. Merge operation consists of 2 steps. First, if q′est is a final state, then q becomes one as well (if it was not already the case) and the number of sequences ending in q′ is added to the number of sequences ending in q. Second, incoming arcs at q′sont redirected to q. If such arcs already exist, the number of passing sequences in each incoming arc is added to the existing arc. The Fold operation is a recursive function consisting in merging the successor nodes q′ into q and the corresponding successor nodes of q respectively.

# %%
def Original_Alergia(sequences, alpha):
    '''
    Original version of the Alergia Algorithm
    
    Arguments: 
    sequences -- the sequences to build the Trie and then convert it in a PFA
    alpha -- an int between 0 and 1. It represents a parameter of the Hoeffding bounds. 
    
    Return:
    A DPA according to the sequences we have
    '''
    print('Starting building corresponding Trie \n')
    trie = PrefixTree()
    trie.alphabet = list({l for word in sequences for l in word})
    for subseq in sequences:
        trie.insert(subseq)
    print(trie.size())
    #print(trie.leaf())
    #initial = trie.size()
    red = []
    red.append(trie.root)
    blue = []
    for x in trie.root.children[1:]:
        if(x[2] not in blue):
            blue.append(x[2])
    t0 = 0.5
    
    print('Running Alergia on trie \n')
    while(len(blue) > 0):
        qb = blue[0]
        blue.remove(qb)
        promote = True
        if(qb.get_frequency() >= t0):
            for qr in red:
                if(Original_AlergiaCompatible(trie, qr, qb, alpha)):
                    #print('Merge accepted...')
                    #print(qr)
                    #print(qb)
                    trie = Original_MergeFold(trie, qr, qb)
                    promote = False
                    for child in qr.children[1:]:    
                        if(child[2] not in blue and child[2].state != qr.state and child[2] not in red):
                            blue.append(child[2])
                    break
        
            if(promote == True):
                #print('No merge possible...')
                red.append(qb)
                for child in qb.children[1:]:
                    if(child[2] not in blue and child[2] not in red):
                        blue.append(child[2])
        else:
            continue
    
    trie.transform2proba()
    print('Algo done')
    return trie

def Original_AlergiaCompatible(trie, qr, qb, alpha):
    '''
    Sub-method of the Alergia main one. It tells us if 2 nodes (a red and a blue) are compatible
    
    Arguments:
    trie -- the current trie we are working on
    qr -- a red node 
    qb -- a blue node
    alpha -- parameter alpha mentionned above
    
    Return:
    a boolean saying whether or not the 2 nodes in arguments are compatible
    '''
    correct = True
    if(Original_AlergiaTest(qr.children[0][1], qr.get_frequency(), qb.children[0][1], qb.get_frequency(), alpha) == False):
        correct = False
    
    for a in trie.alphabet:
        for children_r in qr.children:
            for children_b in qb.children:
                if(a == children_r[1] and a == children_b[1]):
                    if(Original_AlergiaTest(children_r[2], children_r.get_frequency(), children_b[2], children_b.get_frequency(), alpha) == False):
                        correct = False
    return correct
  
def Original_AlergiaTest(f1, n1, f2, n2, alpha):
    '''
    Sub-method of the Alergia compatible method. It computes the hoeffding bounds and compare it to the gamma threshold
    
    Arguments:
    f1 -- incoming frequency of the node 1
    n1 -- number of times a word ends in node 1
    f2 -- incoming frequency of the node 2
    n2 -- number of times a word ends in node 2
    1 & 2 refers to the nodes we want to compare (i.e a node Red and a node Blue)
    alpha -- same parameter alpha as mentionned
    
    Return:
    True if gamma < hoeffding (then, the nodes are compatible)
    False if not
    '''
    gamma = math.fabs(f1/n1 - f2/n2)
    root = math.sqrt(1/(2*math.log(2/alpha)))
    summ = (1/math.sqrt(n1)) + (1/math.sqrt(n2))
    hoeffding = root * summ
    return gamma < hoeffding

def Original_MergeFold(trie, qr, qb): 
    '''
    MERGE OPERATION: 
    To merge a BLUE node into a RED node, all the ingoing links of BLUE node are redirected to the RED node. 
    If the RED node already has an ingoing link with the same item attribute as a redirected link, then only the frequencies are added. 
    Next, the BLUE node attribute is added to the RED node attribute.
    
    FOLD OPERATION:
    When a BLUE node merges into a RED node, all children of BLUE node are recursively merged into children of the RED node with the same item attribute link.
    If the link with an item attribute doesn't exist in the RED node, a new child is inserted.
    
    Arguments:
    trie -- the current Trie we are working on
    qr -- the red node 
    qb -- the blue node to merge
    '''
    q = qb.previous[0]
    
    if qb.text[-1] not in qr.text:
        qr.text = qr.text+ ', ' + qb.text[-1]
        
    for child in q.children:
        if(child[2].state == qb.state):
            child[2] = qr 
            
    qr.children[0][1] += qb.children[0][1]
    
    words = trie.starts_with('', current = qb)
    
    for word in words:
        trie.insert(word)
        
    return trie

# %%
# %time dfa = Original_Alergia(seq, 0.5)
print(dfa.size())
# Out:
# Starting building corresponding Trie
#
# 115
# Running Alergia on trie
#
# Algo done
# Wall time: 7 ms
# 11

# %%
def Relaxed_Alergia(sequences, alpha):
    '''
    Our version of the Alergia algorithm. It tries to recursively merge all the pairs of nodes, from the root to the leaves.
    Unlike the original version, the difference is that it does not test the compatibility of children of these pairs of nodes.
    
    Arguments: 
    sequences -- the sequences to build the Trie and then convert it in a PFA
    alpha -- an int between 0 and 1. It represents a parameter of the Hoeffding bounds. 
    
    Return:
    A DPA according to the sequences we have
    '''
    
    print('Starting building corresponding Trie \n')
    
    trie = PrefixTree()
    
    trie.alphabet = list({l for word in sequences for l in word})
    
    for subseq in sequences:
        trie.insert(subseq)
        
    #print(trie.size())
    #print(trie.leaf())
    #initial = trie.size()
    red = []
    
    red.append(trie.root)
    
    blue = []
    
    for x in trie.root.children[1:]:
        if(x[2] not in blue):
            blue.append(x[2])
            
    t0 = 0.5
    
    print('Running Alergia on trie \n')
    
    while(len(blue) > 0):
        qb = blue[0]
        blue.remove(qb)
        promote = True
        if(qb.get_frequency() >= t0):
            for qr in red:
                if(AlergiaCompatible(trie, qr, qb, alpha)):
                    #print('Merge accepted...')
                    #print(qr)
                    #print(qb)
                    trie = MergeFold(trie, qr, qb)
                    promote = False
                    for child in qr.children[1:]:    
                        if(child[2] not in blue and child[2].state != qr.state and child[2] not in red):
                            blue.append(child[2])
                    break
        
            if(promote == True):
                #print('No merge possible...')
                red.append(qb)
                for child in qb.children[1:]:
                    if(child[2] not in blue and child[2] not in red):
                        blue.append(child[2])
        else:
            continue
    
    trie.transform2proba()
    print('Algo done')
    return trie

def AlergiaCompatible(trie, qr, qb, alpha):
    '''
    Sub-method of the Alergia main one. It tells us if 2 nodes (a red and a blue) are compatible
    
    Arguments:
    trie -- the current trie we are working on
    qr -- a red node 
    qb -- a blue node
    alpha -- parameter alpha mentionned above
    
    Return:
    a boolean saying whether or not the 2 nodes in arguments are compatible
    '''
    correct = True
    
    if(AlergiaTest(qr.children[0][1], qr.get_frequency(), qb.children[0][1], qb.get_frequency(), alpha) == False):
        correct = False
    
    return correct
  
def AlergiaTest(f1, n1, f2, n2, alpha):
    '''
    Sub-method of the Alergia compatible method. It computes the hoeffding bounds and compare it to the gamma threshold
    
    Arguments:
    f1 -- incoming frequency of the node 1
    n1 -- number of times a word ends in node 1
    f2 -- incoming frequency of the node 2
    n2 -- number of times a word ends in node 2
    1 & 2 refers to the nodes we want to compare (i.e a node Red and a node Blue)
    alpha -- same parameter alpha as mentionned
    
    Return:
    True if gamma < hoeffding (then, the nodes are compatible)
    False if not
    '''
    gamma = math.fabs(f1/n1 - f2/n2)
    root = math.sqrt(1/(2*math.log(2/alpha)))
    summ = (1/math.sqrt(n1)) + (1/math.sqrt(n2))
    hoeffding = root * summ
    return gamma < hoeffding

def MergeFold(trie, qr, qb): 
    '''
    MERGE OPERATION: 
    To merge a BLUE node into a RED node, all the ingoing links of BLUE node are redirected to the RED node. 
    If the RED node already has an ingoing link with the same item attribute as a redirected link, then only the frequencies are added. 
    Next, the BLUE node attribute is added to the RED node attribute.
    
    FOLD OPERATION:
    When a BLUE node merges into a RED node, all children of BLUE node are recursively merged into children of the RED node with the same item attribute link.
    If the link with an item attribute doesn't exist in the RED node, a new child is inserted.
    
    Arguments:
    trie -- the current Trie we are working on
    qr -- the red node 
    qb -- the blue node to merge
    '''
    q = qb.previous[0]
    
    if qb.text[-1] not in qr.text:
        qr.text = qr.text+ ', ' + qb.text[-1]
        
    for child in q.children:
        if(child[2].state == qb.state):
            child[2] = qr 
            
    qr.children[0][1] += qb.children[0][1]
    
    words = trie.starts_with('', current = qb)
    
    for word in words:
        trie.insert(word)
        
    return trie

# %%
# %time dfa_2 = Relaxed_Alergia(seq, 0.5)
print(dfa_2.size())
# Out:
# Starting building corresponding Trie
#
# Running Alergia on trie
#
# Algo done
# Wall time: 5 ms
# 11

# %%
dfa_2.display()
# Out:
# ====================================================================================
# symb:λ, 9, 1, 7, 8, 3, 0, 2, 4, 5 state:232 -> children:[['#', 0.11179173047473201, <__main__.TrieNode object at 0x000001D9EDCF20C8>], ['9', 0.0444104134762634, <__main__.TrieNode object at 0x000001D9EDCF20C8>], ['1', 0.06431852986217458, <__main__.TrieNode object at 0x000001D9EDCF20C8>], ['7', 0.03215926493108729, <__main__.TrieNode object at 0x000001D9EDCF20C8>], ['8', 0.18223583460949463, <__main__.TrieNode object at 0x000001D9EDCF20C8>], ['3', 0.06278713629402756, <__main__.TrieNode object at 0x000001D9EDCF20C8>], ['0', 0.1332312404287902, <__main__.TrieNode object at 0x000001D9EDCF20C8>], ['2', 0.08269525267993874, <__main__.TrieNode object at 0x000001D9EDCF20C8>], ['4', 0.12098009188361408, <__main__.TrieNode object at 0x000001D9EDCF20C8>], ['6', 0.06891271056661562, <__main__.TrieNode object at 0x000001D9EDC5DC08>], ['5', 0.09647779479326186, <__main__.TrieNode object at 0x000001D9EDCF20C8>]]
#
# symb:6 state:261 -> children:[['#', 0.26666666666666666, <__main__.TrieNode object at 0x000001D9EDC5DC08>], ['5', 0.15555555555555556, <__main__.TrieNode object at 0x000001D9EDC5DF88>], ['8', 0.15555555555555556, <__main__.TrieNode object at 0x000001D9EDC5D388>], ['4', 0.1111111111111111, <__main__.TrieNode object at 0x000001D9EDC5DD48>], ['3', 0.044444444444444446, <__main__.TrieNode object at 0x000001D9EDC79188>], ['0', 0.13333333333333333, <__main__.TrieNode object at 0x000001D9EDCE9B48>], ['1', 0.022222222222222223, <__main__.TrieNode object at 0x000001D9EDC7A588>], ['2', 0.06666666666666667, <__main__.TrieNode object at 0x000001D9EDC70BC8>], ['9', 0.044444444444444446, <__main__.TrieNode object at 0x000001D9EDC7BE48>]]
#
# symb:65 state:262 -> children:[['#', 1.0, <__main__.TrieNode object at 0x000001D9EDC5DF88>]]
#
# symb:68 state:265 -> children:[['#', 1.0, <__main__.TrieNode object at 0x000001D9EDC5D388>]]
#
# symb:64 state:266 -> children:[['#', 1.0, <__main__.TrieNode object at 0x000001D9EDC5DD48>]]
#
# symb:63 state:294 -> children:[['#', 1.0, <__main__.TrieNode object at 0x000001D9EDC79188>]]
#
# symb:60 state:315 -> children:[['#', 0.8333333333333334, <__main__.TrieNode object at 0x000001D9EDCE9B48>], ['5', 0.16666666666666666, <__main__.TrieNode object at 0x000001D9EDC7A448>]]
#
# symb:605 state:329 -> children:[['#', 1.0, <__main__.TrieNode object at 0x000001D9EDC7A448>]]
#
# symb:61 state:330 -> children:[['#', 1.0, <__main__.TrieNode object at 0x000001D9EDC7A588>]]
#
# symb:62 state:335 -> children:[['#', 1.0, <__main__.TrieNode object at 0x000001D9EDC70BC8>]]
#
# symb:69 state:342 -> children:[['#', 1.0, <__main__.TrieNode object at 0x000001D9EDC7BE48>]]
#
# ====================================================================================

# %%
dfa.display()
# Out:
# ====================================================================================
# symb:λ, 9, 1, 7, 8, 3, 0, 2, 4, 5 state:116 -> children:[['#', 0.11179173047473201, <__main__.TrieNode object at 0x000001D9EDCE9A48>], ['9', 0.0444104134762634, <__main__.TrieNode object at 0x000001D9EDCE9A48>], ['1', 0.06431852986217458, <__main__.TrieNode object at 0x000001D9EDCE9A48>], ['7', 0.03215926493108729, <__main__.TrieNode object at 0x000001D9EDCE9A48>], ['8', 0.18223583460949463, <__main__.TrieNode object at 0x000001D9EDCE9A48>], ['3', 0.06278713629402756, <__main__.TrieNode object at 0x000001D9EDCE9A48>], ['0', 0.1332312404287902, <__main__.TrieNode object at 0x000001D9EDCE9A48>], ['2', 0.08269525267993874, <__main__.TrieNode object at 0x000001D9EDCE9A48>], ['4', 0.12098009188361408, <__main__.TrieNode object at 0x000001D9EDCE9A48>], ['6', 0.06891271056661562, <__main__.TrieNode object at 0x000001D9EDC57B08>], ['5', 0.09647779479326186, <__main__.TrieNode object at 0x000001D9EDCE9A48>]]
#
# symb:6 state:145 -> children:[['#', 0.26666666666666666, <__main__.TrieNode object at 0x000001D9EDC57B08>], ['5', 0.15555555555555556, <__main__.TrieNode object at 0x000001D9EBA38D08>], ['8', 0.15555555555555556, <__main__.TrieNode object at 0x000001D9EDC57A88>], ['4', 0.1111111111111111, <__main__.TrieNode object at 0x000001D9EDC57108>], ['3', 0.044444444444444446, <__main__.TrieNode object at 0x000001D9EDC7A508>], ['0', 0.13333333333333333, <__main__.TrieNode object at 0x000001D9EDC5EC48>], ['1', 0.022222222222222223, <__main__.TrieNode object at 0x000001D9EDC72588>], ['2', 0.06666666666666667, <__main__.TrieNode object at 0x000001D9EDC73388>], ['9', 0.044444444444444446, <__main__.TrieNode object at 0x000001D9EDCDD3C8>]]
#
# symb:65 state:146 -> children:[['#', 1.0, <__main__.TrieNode object at 0x000001D9EBA38D08>]]
#
# symb:68 state:149 -> children:[['#', 1.0, <__main__.TrieNode object at 0x000001D9EDC57A88>]]
#
# symb:64 state:150 -> children:[['#', 1.0, <__main__.TrieNode object at 0x000001D9EDC57108>]]
#
# symb:63 state:178 -> children:[['#', 1.0, <__main__.TrieNode object at 0x000001D9EDC7A508>]]
#
# symb:60 state:199 -> children:[['#', 0.8333333333333334, <__main__.TrieNode object at 0x000001D9EDC5EC48>], ['5', 0.16666666666666666, <__main__.TrieNode object at 0x000001D9EDCF0F48>]]
#
# symb:605 state:213 -> children:[['#', 1.0, <__main__.TrieNode object at 0x000001D9EDCF0F48>]]
#
# symb:61 state:214 -> children:[['#', 1.0, <__main__.TrieNode object at 0x000001D9EDC72588>]]
#
# symb:62 state:219 -> children:[['#', 1.0, <__main__.TrieNode object at 0x000001D9EDC73388>]]
#
# symb:69 state:226 -> children:[['#', 1.0, <__main__.TrieNode object at 0x000001D9EDCDD3C8>]]
#
# ====================================================================================
